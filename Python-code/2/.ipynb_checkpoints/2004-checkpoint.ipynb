# %%
# 1：问题分解
# 2：使用数字和字符串
# 3：解决位置问题
# 4：编码测试

# 难点：怎么把 输入的运算符 进行实际运算

num1 = input('num1')
num2 = input('num2')
operator = input('operator')

print(type(num1))

# print(int(num1) operator int(num2))

sum = eval(f"{num1} {operator} {num2}")
print(sum)
# Out:
# num1 1.1
# num2 2.2
# operator *
# <class 'str'>
# 2.4200000000000004
