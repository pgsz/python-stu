# %%
print(int(123.456))  # 123
print(float(123.456))  # 123.456
print(float(123))  # 123.0
# Out:
# 123
# 123.456
# 123.0

# %%
print(type(123))  # <class 'int'>
print(type(123.456))  # <class 'float'>
print(type('123'))  # <class 'str'>
print(type(int('123')))  # <class 'int'>
print(type(int('123.456')))  # 报错：invalid literal for int() with base 10: '123.456'
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(type('123'))  # <class 'str'>
#       4 print(type(int('123')))  # <class 'int'>
# ----> 5 print(type(int('123.456')))
#
# ValueError: invalid literal for int() with base 10: '123.456'

# %%
num1 = input('数字一')
num2 = input('数字二')
print(float(num1) + float(num2))
# Out:
# 数字一 12.56
# 数字二 22.56
# 35.12
