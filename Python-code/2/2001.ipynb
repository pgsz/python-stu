# %%
print('hello Python')
# Out:
# hello Python

# %%
input("请输入指令: \n")
# Out:
# 请输入指令:
#  123456
# '123456'

# %%
var1 = input("输入第一行内容：\n")
var2 = input("输入第二行内容：\n")
print(var1)
print(var2)
# Out:
# 输入第一行内容：
#  第一行第一行第一行
# 输入第二行内容：
#  第二行第二行第二行
# 第一行第一行第一行
# 第二行第二行第二行

# %%
print("hellow \" python")
# Out:
# hellow " python

# %%
print('hellow " python')
# Out:
# hellow " python

# %%
print('''
hellow

''')
# Out:
# hellow
# print

# %%
x = 123
print(f"x的值是{x}")
# Out:
# x的值是123

# %%
'x' in '123x456'
# Out:
# True

# %%
print('x' in '123x456')
# Out:
# True

# %%
'x' not in '123x456'
# Out:
# False

# %%
'abc' + 'xyz'
# Out:
# 'abcxyz'

# %%
x = 'abc'
y = 'xyz'
print(x + y)
print(x * 3)
# Out:
# abcxyz
# abcabcabc

# %%
s = 'abcde'
print(s[0])
print(s[3])
print(s[-1])
print(s[1:3])
print(s[1:4:2])
print(s[::-1])  # 反转
# Out:
# a
# d
# e
# bc
# bd
# edcba

# %%
s = 'abcde'
print(s[0])
print(s[3])
print(s[-1])
print(s[1:3])
print(s[1:4:2])
print(s[::-1])  # 反转
# Out:
# a
# d
# e
# bc
# bd
# edcba

# %%
x = 'python'
x[0] # p
x[1:3] # yt
x[1:] # ython
x[::-1] # nohtyp
# Out:
# 'nohtyp'

# %%
print('Letters and spaces'.isalpha())
print('LettersOnly'.isalpha())
# Out:
# False
# True

# %%
print(', '.join(['spam', 'spam', 'spam']))
print('-'.join('Python'))
# Out:
# spam, spam, spam
# 'P-y-t-h-o-n'

# %%
x = 'abcdefg'
print(x.startswith('a'))
print(x.startswith('a', 1))
# Out:
# True
# False

# %%
x = '''
Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
'''
print(x.count('better'))
# Out:
# 3

# %%
name = input('请输入你的姓名')
print(f"Hello {name.capitalize()}")
print(f"Hello {name[0].upper()}{name[1:]}")
# Out:
# 请输入你的姓名 peng
# Hello Peng
# Hello Peng
